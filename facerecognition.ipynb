# %% [markdown]
# <a href="https://colab.research.google.com/github/Gayatridivi/Divi/blob/master/facerecognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install face_recognition

# %%
import face_recognition
import cv2
import os
from google.colab.patches import cv2_imshow



known_encodings = []
known_names = []
known_dir = 'known'

for file in os.listdir(known_dir):
    print(file)
    img = cv2.imread(known_dir + '/' + file)
    img_enc = face_recognition.face_encodings(img)[0]
    known_encodings.append(img_enc)
    known_names.append(file.split('.')[0])

unknown_dir = 'unknown'
for file in os.listdir(unknown_dir):
    print("Processing", file)
    img =  read_img(unknown_dir + '/' + file)
    img_enc = face_recognition.face_encodings(img)[0]

    results = face_recognition.compare_faces(known_encodings, img_enc)
    # print(face_recognition.face_distance(known_encodings, img_enc))

    for i in range(len(results)):
        if results[i]:
            name = known_names[i]
            (top, right, bottom, left) = face_recognition.face_locations(img)[0]
            cv2.rectangle(img, (left, top), (right, bottom), (0, 0, 255), 2)
            cv2.putText(img, name, (left+2, bottom+20), cv2.FONT_HERSHEY_PLAIN, 1, (255, 255, 255), 1)
            cv2_imshow(img)
# Out:
# amma.jpg
# chaitu.jpg
# adhya.jpg
# Processing hasmi.jpg
# Processing 3.jpg
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F134C656470>
# Processing 1.jpg
# <PIL.Image.Image image mode=RGB size=500x1082 at 0x7F134C6567B8>
# Processing 2.jpg
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F134C6567F0>
